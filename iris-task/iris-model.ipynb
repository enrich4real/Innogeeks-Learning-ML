# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
encoder = LabelEncoder()

# %%
df['species']=encoder.fit_transform(df['species'])

# %%
df["species"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
df.head(30)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0
# 5            5.4          3.9           1.7          0.4        0
# 6            4.6          3.4           1.4          0.3        0
# 7            5.0          3.4           1.5          0.2        0
# 8            4.4          2.9           1.4          0.2        0
# 9            4.9          3.1           1.5          0.1        0
# 10           5.4          3.7           1.5          0.2        0
# 11           4.8          3.4           1.6          0.2        0
# 12           4.8          3.0           1.4          0.1        0
# 13           4.3          3.0           1.1          0.1        0
# 14           5.8          4.0           1.2          0.2        0
# 15           5.7          4.4           1.5          0.4        0
# 16           5.4          3.9           1.3          0.4        0
# 17           5.1          3.5           1.4          0.3        0
# 18           5.7          3.8           1.7          0.3        0
# 19           5.1          3.8           1.5          0.3        0
# 20           5.4          3.4           1.7          0.2        0
# 21           5.1          3.7           1.5          0.4        0
# 22           4.6          3.6           1.0          0.2        0
# 23           5.1          3.3           1.7          0.5        0
# 24           4.8          3.4           1.9          0.2        0
# 25           5.0          3.0           1.6          0.2        0
# 26           5.0          3.4           1.6          0.4        0
# 27           5.2          3.5           1.5          0.2        0
# 28           5.2          3.4           1.4          0.2        0
# 29           4.7          3.2           1.6          0.2        0

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %%
x=df.drop('species',axis=1)
y=df['species']

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 150, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 10)

# %%
model=RandomForestRegressor(n_estimators=10,random_state=0)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
model
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
model.score(x_test,y_test)
# Out:
# 0.9940119760479041

# %%
model.predict(x_test)
# Out:
# array([1. , 2. , 0. , 1. , 0. , 1. , 1.3, 1. , 0. , 1. , 1. , 2. , 1. ,
#        0. , 0. , 2. , 1. , 0. , 0. , 0. , 2. , 2. , 1.9, 0. , 1. , 0. ,
#        1. , 1. , 1. , 2. ])

# %%
model.predict([[6.7,3.0,5.2,2.3]])
# Out:
# /home/kakeshi/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([2.])

# %%
sns.lineplot(data=iris,x="sepal_length",y="petal_length",hue="species")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x7f2ff455b250>,
#  <matplotlib.lines.Line2D at 0x7f2ff455b100>,
#  <matplotlib.lines.Line2D at 0x7f2ff5056280>,
#  <matplotlib.lines.Line2D at 0x7f2ff50563a0>,
#  <matplotlib.lines.Line2D at 0x7f2ff50564c0>]

# %%
sns.pairplot(df)
